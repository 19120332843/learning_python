# %%
import matplotlib
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error , r2_score
import numpy as np
from pandas import read_csv
from matplotlib import pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import pandas as pd
import sklearn.metrics as sm
from numpy import *
from operator import *

#导入数据
data = read_csv('data.csv',encoding='GBK',header = 0)

#数据预处理
np.isnan(data).any()  # 检查数据中是否有缺失值
data.dropna(inplace=True)   #删除有缺失值的行
X1 = data[['DamageTaken']]
x =  X1/100
Y = data[['Heal']]
y =  Y/100
z = data[['champion']]
print(z.shape)
print(z.values[0])

#建模
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.5, random_state=123)  #使用测试集，训练集
model = linear_model.LinearRegression()
poly_reg = PolynomialFeatures(degree = 4 )
X_poly = poly_reg.fit_transform(train_x)
model1 = model.fit(X_poly , train_y)
X = np.arange(0,450,5)
X = X.reshape(-1,1)

#画散点图
j1 = 0
j2 = 0
j3 = 0
j4 = 0
x1 = []
x2 = []
x3 = []
x4 = []
y1 = []
y2 = []
y3 = []
y4 = []
for i in range(len(z)):
    if z.values[i] < 80 :
        #plt.scatter(x.values[i], y.values[i],color = 'Orange')
        x1.append(x.values[i])
        y1.append(y.values[i])
        #x1=np.array(list x1)
        j1 = j1+1
        train_x, test_x, train_y, test_y = train_test_split(x1, y1, test_size=0.5, random_state=123)  # 使用测试集，训练集
        #print(train_x.shape)
        train_x = train_x.reshape(-1, 1)
        train_y = train_y.reshape(-1, 1)
        model1 = linear_model.LinearRegression()
        poly_reg = PolynomialFeatures(degree=1)
        model1.fit(train_x, train_y)
        X1 = np.arange(0, 450, 5)
        X1 = X.reshape(-1, 1)
        plt.plot(X1, model1.predict(X1), color='Orange')
    elif z.values[i] >=80 and z.values[i]<200 :
        plt.scatter(x.values[i], y.values[i],color='black')
    elif z.values[i] >= 200 and z.values[i] < 400:
        plt.scatter(x.values[i], y.values[i], color = 'red')
    else:
        plt.scatter(x.values[i], y.values[i], color='blue')


print(x1)
plt.xlabel("DamageTaken")#设置X轴标签
plt.ylabel('Heal')#设置Y轴标签

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-30bb78b03567> in <module>
#       1 import matplotlib
# ----> 2 from sklearn import linear_model
#       3 from sklearn.model_selection import train_test_split
#       4 from sklearn.metrics import mean_squared_error , r2_score
#       5 import numpy as np
#
# D:\Python37\lib\site-packages\sklearn\__init__.py in <module>
#      74 else:
#      75     from . import __check_build
# ---> 76     from .base import clone
#      77     from .utils._show_versions import show_versions
#      78
#
# D:\Python37\lib\site-packages\sklearn\base.py in <module>
#      14
#      15 from . import __version__
# ---> 16 from .utils import _IS_32BIT
#      17
#      18 _DEFAULT_TAGS = {
#
# D:\Python37\lib\site-packages\sklearn\utils\__init__.py in <module>
#      18 from ..exceptions import DataConversionWarning
# ...
