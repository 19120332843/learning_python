# %%
import os
import sys
import pandas as pd
import numpy as np

df = pd.read_csv("F:\\gitworkspace\\python\\e-nose-cnn\\draw_test\\draw_test.csv")
data = df.values
data = list(map(list,zip(*data)))
data = pd.DataFrame(data)
data = data[range(120)]
data.to_csv(os.path.join("F:\\gitworkspace\\python\\e-nose-cnn\\draw_test", "tran.csv"), encoding='utf_8_sig',  index=False, header=1)
# print(data)

# %%
,
