# %%
import os
import pandas as pd
import numpy as np


def listdir(path, list_name):  # 传入存储的list
    for file in os.listdir(path):
        file_path = os.path.join(path, file)
        if os.path.isdir(file_path):
            listdir(file_path, list_name)
        else:
            list_name.append(file_path)

file_paths = []
listdir("F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1", file_paths)#F:\gitworkspace\python\e-nose-cnn\nos-data\3times7class\binglang\1
print(file_paths)
a = 0
for i in file_paths:
    try:
        #nos2csv
        data = pd.read_csv(i, sep='\t', dtype=np.object,
            skiprows=52, header=None, engine='python')
        # print(data)
        data = data.loc[0:119]
        # print(data)
        data = data[range(10)]
        # print(data)
        data.to_csv(os.path.join("F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\2", "{0[6]}-{1}.csv".format(i.split("\\"), a)), encoding='utf_8_sig', index=False, header=1)#utf_8_sig
        a += 1
    except Exception as e:
        print(i)
# Out:
# ['F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\0001 (2).nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\0001 (3).nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\0001 (4).nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\0001 (5).nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\0001 (6).nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\150ml 5g 20min 温度 ：280001.2湿度42% 生枳壳 160201江西至信', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳150901江西至信0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160201江西至信0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160201至信江西0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160501江西至信0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160601江西建泽0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160601江西至信0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160602江西建泽0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160603江西建泽0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160605江西建泽0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160701江西建泽0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160702江西建泽0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160703江西建泽0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160704江西建泽0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160705江西建泽0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160706江西建泽0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160707江西建泽0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160708江西建泽0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160709江西建泽0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160801江西建泽0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160802江西建泽0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160803江西建泽0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160804江西建泽0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160805江西建泽0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160806江西建泽0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\制枳壳160807江西建泽0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\生枳壳10g 160201江西至信0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\生枳壳150801湖南0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\生枳壳150901江西至信0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\生枳壳1510099湖南0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\生枳壳151102湖南0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\生枳壳15g 160201江西至信0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\生枳壳160101011湖南0001.nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\生枳壳160201江西至信0001 (2).nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos-data\\3times7class\\zhike\\1\\生枳壳160201江西至信0001 (3).nos', 'F:\\gitworkspace\\python\\e-nose-cnn\\nos ...
